# %% [markdown]
# Importing Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import pandas as pd
import numpy as np

# %% [markdown]
# Importing Data and converting categorical features to numerical features

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/MyDrive/flight_data.csv")
df['Scheduled Departure Time'] = pd.to_datetime(df['Scheduled Departure Time'])
df['Actual Departure Time'] = pd.to_datetime(df['Actual Departure Time'])
df['Departure Delay (minutes)'] = (df['Actual Departure Time'] - df['Scheduled Departure Time']).dt.total_seconds() / 60
df['Flight Number'] = df['Flight Number'].str.extract(r'(\d+)').astype(int)  # One-Hot Encoding
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         Flight Number Scheduled Departure Time Actual Departure Time  \
# 0                 885      2024-05-20 11:51:21   2024-07-10 02:38:54
# 1                 930      2024-01-23 06:56:23   2024-07-07 02:53:44
# 2                 478      2024-05-30 09:18:39   2024-12-05 01:00:54
# 3                 637      2024-08-15 05:21:47   2024-09-21 13:23:42
# 4                 318      2024-07-25 15:29:58   2024-03-21 15:05:54
# ...               ...                      ...                   ...
# 199995             73      2024-09-04 21:05:15   2024-01-13 21:04:10
# 199996            732      2024-01-25 21:17:59   2024-01-21 00:57:55
# 199997            519      2024-10-19 08:31:24   2024-06-04 03:40:50
# 199998            585      2024-01-04 04:35:20   2024-02-06 01:57:18
# 199999            590      2024-07-13 06:04:41   2024-09-04 04:21:54
#
#         Delay (Minutes)  Aircraft Utilization (Hours/Day)  \
# 0                    50                             12.36
# 1                    27                             14.53
# 2                   108                             10.73
# 3                    64                             15.10
# 4                    30                             13.46
# ...                 ...                               ...
# 199995               28                             14.86
# 199996               48                              8.67
# 199997               83                             12.80
# 199998               55                             12.53
# 199999              109                              8.14
#
#         Turnaround Time (Minutes)  Load Factor (%)  Fleet Availability (%)  \
# 0                             115            79.18                   96.24
# 1                              83            98.59                   80.49
# 2                              87            67.44                   97.90
# 3                              99            69.01                   80.17
# 4                             114            50.36                   82.23
# ...                           ...              ...                     ...
# 199995                         38            60.12                   97.56
# 199996                         34            77.77                   87.05
# 199997                         58            93.12                   80.84
# 199998                        115            99.04                   85.82
# 199999                         35            74.97                   72.95
#
#         Maintenance Downtime (Hours)  Fuel Efficiency (ASK)  Revenue (USD)  \
# 0                               9.21                   4.15       10953.75
# 1                               1.55                   3.93       31597.25
# 2                               2.06                   4.26       13700.27
# 3                               6.85                   4.13       39913.01
# 4                               7.30                   4.97       11531.48
# ...                              ...                    ...            ...
# 199995                          8.44                   2.16       20903.43
# 199996                          8.13                   3.26       39601.03
# 199997                          9.80                   3.68       36100.34
# 199998                          6.84                   4.70        8157.56
# 199999                          4.77                   4.80       16808.78
#
#         Operating Cost (USD)  Net Profit Margin (%)  Ancillary Revenue (USD)  \
# 0                   27847.59                  17.90                  1058.68
# 1                    1564.41                   7.70                  2941.32
# 2                   30494.88                   5.84                  1920.45
# 3                   13444.09                  24.09                  3167.79
# 4                   34668.98                   7.18                   619.80
# ...                      ...                    ...                      ...
# 199995              11668.11                  24.11                   856.06
# 199996              29873.77                   7.33                  1037.92
# 199997              16114.79                  21.82                  1441.99
# 199998              15878.50                  17.93                  4584.92
# 199999              28268.46                   8.43                   175.02
#
#         Debt-to-Equity Ratio  Revenue per ASK  Cost per ASK  Profit (USD)  \
# 0                       2.46          2639.46       6710.26     -16893.84
# 1                       2.89          8040.01        398.07      30032.84
# 2                       1.34          3216.03       7158.42     -16794.61
# 3                       0.60          9664.17       3255.23      26468.92
# 4                       0.84          2320.22       6975.65     -23137.50
# ...                      ...              ...           ...           ...
# 199995                  0.53          9677.51       5401.90       9235.32
# 199996                  1.31         12147.56       9163.73       9727.26
# 199997                  2.69          9809.87       4379.02      19985.55
# 199998                  1.26          1735.65       3378.40      -7720.94
# 199999                  1.62          3501.83       5889.26     -11459.68
#
#         Departure Delay (minutes)
# 0                    72887.550000
# 1                   238797.350000
# 2                   271662.250000
# 3                    53761.916667
# 4                  -181464.066667
# ...                           ...
# 199995             -338401.083333
# 199996               -6980.066667
# 199997             -197570.566667
# 199998               47361.966667
# 199999               76217.216667
#
# [200000 rows x 19 columns]

# %% [markdown]
# Understanding data

# %%
df.describe()
# Out:
#        Flight Number       Scheduled Departure Time  \
# count  200000.000000                         200000
# mean      499.667210  2024-06-29 07:21:27.048759808
# min         0.000000            2024-01-01 00:01:53
# 25%       250.000000            2024-03-30 22:12:47
# 50%       499.000000            2024-06-29 10:33:27
# 75%       750.000000     2024-09-27 09:33:27.500000
# max       999.000000            2024-12-27 05:14:39
# std       288.569873                            NaN
#
#                Actual Departure Time  Delay (Minutes)  \
# count                         200000     200000.00000
# mean   2024-06-29 08:55:04.200095232         59.35885
# min              2024-01-01 00:03:34          0.00000
# 25%    2024-03-30 15:40:28.249999872         29.00000
# 50%              2024-06-28 20:10:25         59.00000
# 75%       2024-09-28 03:54:08.500000         89.00000
# max              2024-12-27 05:07:36        119.00000
# std                              NaN         34.67602
#
#        Aircraft Utilization (Hours/Day)  Turnaround Time (Minutes)  \
# count                     200000.000000              200000.000000
# mean                          12.003438                  74.451680
# min                            8.000000                  30.000000
# 25%                            9.990000                  52.000000
# 50%                           12.010000                  74.000000
# 75%                           14.010000                  97.000000
# max                           16.000000                 119.000000
# std                            2.311966                  25.977826
#
#        Load Factor (%)  Fleet Availability (%)  Maintenance Downtime (Hours)  \
# count    200000.000000           200000.000000                 200000.000000
# mean         74.997178               85.001378                      5.503103
# min          50.000000               70.000000                      1.000000
# 25%          62.500000               77.480000                      3.250000
# 50%          74.960000               85.000000                      5.500000
# 75%          87.530000               92.530000                      7.760000
# max         100.000000              100.000000                     10.000000
# std          14.439393                8.672413                      2.601257
#
#        Fuel Efficiency (ASK)  Revenue (USD)  Operating Cost (USD)  \
# count          200000.000000  200000.000000         200000.000000
# mean                3.496959   25571.448338          20429.003323
# min                 2.000000    1000.060000            800.030000
# 25%                 2.750000   13297.042500          10609.022500
# 50%                 3.490000   25566.300000          20410.885000
# 75%                 4.250000   37860.402500          30245.907500
# max                 5.000000   49999.950000          39999.840000
# std                 0.865309   14158.512116          11316.410641
#
#        Net Profit Margin (%)  Ancillary Revenue (USD)  Debt-to-Equity Ratio  \
# count          200000.000000            200000.000000         200000.000000
# mean               15.011169              2550.025537              1.752445
# min                 5.000000               100.020000              0.500000
# 25%                10.010000              1325.570000              1.130000
# 50%                15.000000              2544.210000              1.750000
# 75%                20.010000              3776.387500              2.370000
# max                25.000000              5000.000000              3.000000
# std                 5.778340              1414.291993              0.720194
#
#        Revenue per ASK   Cost per ASK   Profit (USD)  \
# count    200000.000000  200000.000000  200000.000000
# mean       7818.578193    6245.613443    5142.445015
# min         203.110000     164.830000  -38973.960000
# 25%        3812.782500    3041.547500   -7983.690000
# 50%        7315.460000    5834.705000    5216.975000
# 75%       10909.272500    8715.670000   18269.647500
# max       24999.340000   19928.340000   49054.690000
# std        4947.028923    3957.358310   18123.595784
#
#        Departure Delay (minutes)
# count              200000.000000
# mean                   93.619189
# min               -519477.383333
# 25%               -151500.054167
# 50%                  -267.025000
# 75%                151647.958333
# max                519267.750000
# std                212045.974801

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Flight Number                     200000 non-null  int64
#  1   Scheduled Departure Time          200000 non-null  datetime64[ns]
#  2   Actual Departure Time             200000 non-null  datetime64[ns]
#  3   Delay (Minutes)                   200000 non-null  int64
#  4   Aircraft Utilization (Hours/Day)  200000 non-null  float64
#  5   Turnaround Time (Minutes)         200000 non-null  int64
#  6   Load Factor (%)                   200000 non-null  float64
#  7   Fleet Availability (%)            200000 non-null  float64
#  8   Maintenance Downtime (Hours)      200000 non-null  float64
#  9   Fuel Efficiency (ASK)             200000 non-null  float64
#  10  Revenue (USD)                     200000 non-null  float64
#  11  Operating Cost (USD)              200000 non-null  float64
#  12  Net Profit Margin (%)             200000 non-null  float64
#  13  Ancillary Revenue (USD)           200000 non-null  float64
#  14  Debt-to-Equity Ratio              200000 non-null  float64
#  15  Revenue per ASK                   200000 non-null  float64
#  16  Cost per ASK                      200000 non-null  float64
#  17  Profit (USD)                      200000 non-null  float64
#  18  Departure Delay (minutes)         200000 non-null  float64
# dtypes: datetime64[ns](2), float64(14), int64(3)
# memory usage: 29.0 MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# Profit is correlated with Revenue, Operating Cost, Cost per ASK and Revenue per ASK

# %%
sns.histplot(df["Profit (USD)"])
plt.show()

# %% [markdown]
# Splitting Profit with the other features.

# %%
X = df.drop(columns=["Profit (USD)"])
y = df["Profit (USD)"]
X
# Out:
#         Flight Number Scheduled Departure Time Actual Departure Time  \
# 0                 885      2024-05-20 11:51:21   2024-07-10 02:38:54
# 1                 930      2024-01-23 06:56:23   2024-07-07 02:53:44
# 2                 478      2024-05-30 09:18:39   2024-12-05 01:00:54
# 3                 637      2024-08-15 05:21:47   2024-09-21 13:23:42
# 4                 318      2024-07-25 15:29:58   2024-03-21 15:05:54
# ...               ...                      ...                   ...
# 199995             73      2024-09-04 21:05:15   2024-01-13 21:04:10
# 199996            732      2024-01-25 21:17:59   2024-01-21 00:57:55
# 199997            519      2024-10-19 08:31:24   2024-06-04 03:40:50
# 199998            585      2024-01-04 04:35:20   2024-02-06 01:57:18
# 199999            590      2024-07-13 06:04:41   2024-09-04 04:21:54
#
#         Delay (Minutes)  Aircraft Utilization (Hours/Day)  \
# 0                    50                             12.36
# 1                    27                             14.53
# 2                   108                             10.73
# 3                    64                             15.10
# 4                    30                             13.46
# ...                 ...                               ...
# 199995               28                             14.86
# 199996               48                              8.67
# 199997               83                             12.80
# 199998               55                             12.53
# 199999              109                              8.14
#
#         Turnaround Time (Minutes)  Load Factor (%)  Fleet Availability (%)  \
# 0                             115            79.18                   96.24
# 1                              83            98.59                   80.49
# 2                              87            67.44                   97.90
# 3                              99            69.01                   80.17
# 4                             114            50.36                   82.23
# ...                           ...              ...                     ...
# 199995                         38            60.12                   97.56
# 199996                         34            77.77                   87.05
# 199997                         58            93.12                   80.84
# 199998                        115            99.04                   85.82
# 199999                         35            74.97                   72.95
#
#         Maintenance Downtime (Hours)  Fuel Efficiency (ASK)  Revenue (USD)  \
# 0                               9.21                   4.15       10953.75
# 1                               1.55                   3.93       31597.25
# 2                               2.06                   4.26       13700.27
# 3                               6.85                   4.13       39913.01
# 4                               7.30                   4.97       11531.48
# ...                              ...                    ...            ...
# 199995                          8.44                   2.16       20903.43
# 199996                          8.13                   3.26       39601.03
# 199997                          9.80                   3.68       36100.34
# 199998                          6.84                   4.70        8157.56
# 199999                          4.77                   4.80       16808.78
#
#         Operating Cost (USD)  Net Profit Margin (%)  Ancillary Revenue (USD)  \
# 0                   27847.59                  17.90                  1058.68
# 1                    1564.41                   7.70                  2941.32
# 2                   30494.88                   5.84                  1920.45
# 3                   13444.09                  24.09                  3167.79
# 4                   34668.98                   7.18                   619.80
# ...                      ...                    ...                      ...
# 199995              11668.11                  24.11                   856.06
# 199996              29873.77                   7.33                  1037.92
# 199997              16114.79                  21.82                  1441.99
# 199998              15878.50                  17.93                  4584.92
# 199999              28268.46                   8.43                   175.02
#
#         Debt-to-Equity Ratio  Revenue per ASK  Cost per ASK  \
# 0                       2.46          2639.46       6710.26
# 1                       2.89          8040.01        398.07
# 2                       1.34          3216.03       7158.42
# 3                       0.60          9664.17       3255.23
# 4                       0.84          2320.22       6975.65
# ...                      ...              ...           ...
# 199995                  0.53          9677.51       5401.90
# 199996                  1.31         12147.56       9163.73
# 199997                  2.69          9809.87       4379.02
# 199998                  1.26          1735.65       3378.40
# 199999                  1.62          3501.83       5889.26
#
#         Departure Delay (minutes)
# 0                    72887.550000
# 1                   238797.350000
# 2                   271662.250000
# 3                    53761.916667
# 4                  -181464.066667
# ...                           ...
# 199995             -338401.083333
# 199996               -6980.066667
# 199997             -197570.566667
# 199998               47361.966667
# 199999               76217.216667
#
# [200000 rows x 18 columns]

# %% [markdown]
# Scaling the data

# %%
numerical_features = X.select_dtypes(include=np.number).columns
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[numerical_features])
X_scaled
# Out:
# array([[ 1.33532218, -0.26989468,  0.15422512, ..., -1.0469175 ,
#          0.11741361,  0.34329401],
#        [ 1.49126401, -0.93317892,  1.09282271, ...,  0.04476068,
#         -1.4776418 ,  1.12571968],
#        [-0.07508498,  1.40273513, -0.5508044 , ..., -0.93036846,
#          0.23066116,  1.28070957],
#        ...,
#        [ 0.06699535,  0.68177401,  0.34453984, ...,  0.40252378,
#         -0.47167781, -0.93217841],
#        [ 0.29571002, -0.12570246,  0.22775581, ..., -1.22961549,
#         -0.72452894,  0.22291612],
#        [ 0.31303689,  1.43157358, -1.67106603, ..., -0.87259627,
#         -0.09004854,  0.35899662]])

# %% [markdown]
# Training the model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.regularizers import l2




input_shape = (X_train.shape[1],)
# Define the model
model = Sequential([
    Input(shape=input_shape),
    Dense(32, activation='relu'),
    Dense(16, activation='relu',kernel_regularizer=l2(0.001)),
    Dense(8, activation='relu',kernel_regularizer=l2(0.001)),
    Dense(4, activation='relu',kernel_regularizer=l2(0.001)),
    Dense(1)  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=75, batch_size=64, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 191798544.0000 - mae: 9422.0615 - val_loss: 2129247.7500 - val_mae: 1170.1125
# Epoch 2/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 1995958.3750 - mae: 1129.2705 - val_loss: 1222729.8750 - val_mae: 875.5738
# Epoch 3/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 889671.1250 - mae: 732.8250 - val_loss: 282511.6562 - val_mae: 400.0714
# Epoch 4/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 225627.2344 - mae: 359.6093 - val_loss: 116727.7812 - val_mae: 261.9824
# Epoch 5/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 101779.9844 - mae: 243.7969 - val_loss: 63382.9180 - val_mae: 191.2989
# Epoch 6/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 56626.4531 - mae: 181.2686 - val_loss: 40808.7969 - val_mae: 157.0204
# Epoch 7/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 35140.6211 - mae: 142.2532 - val_loss: 23040.3223 - val_mae: 115.6637
# Epoch 8/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 19308.9043 - mae: 105.4401 - val_loss: 10952.1689 - val_mae: 79.3144
# Epoch 9/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 8994.2705 - mae: 71.1003 - val_loss: 5571.9409 - val_mae: 56.6664
# Epoch 10/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 4747.9941 - mae: 52.5594 - val_loss: 3472.8496 - val_mae: 45.2464
# Epoch 11/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 3102.0183 - mae: 43.3113 - val_loss: 2816.1309 - val_mae: 40.7694
# Epoch 12/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2211.9434 - mae: 36.6854 - val_loss: 1665.5653 - val_mae: 31.6753
# Epoch 13/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1753.8351 - mae: 32.6919 - val_loss: 1472.1025 - val_mae: 29.1988
# Epoch 14/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 1457.2485 - mae: 29.8053 - val_loss: 1307.7925 - val_mae: 28.7286
# Epoch 15/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 1248.5151 - mae: 27.6826 - val_loss: 1991.4402 - val_mae: 34.4148
# Epoch 16/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 1105.9082 - mae: 26.0918 - val_loss: 1126.1705 - val_mae: 26.5156
# Epoch 17/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 957.6959 - mae: 24.2699 - val_loss: 1087.7765 - val_mae: 25.6527
# Epoch 18/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 866.4185 - mae: 23.0838 - val_loss: 731.1637 - val_mae: 21.7676
# Epoch 19/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 774.9855 - mae: 21.8610 - val_loss: 629.5732 - val_mae: 19.8042
# Epoch 20/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 702.4807 - mae: 20.7871 - val_loss: 542.8666 - val_mae: 18.2429
# Epoch 21/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 619.3331 - mae: 19.5152 - val_loss: 525.5444 - val_mae: 17.5837
# Epoch 22/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 570.5437 - mae: 18.6764 - val_loss: 426.4469 - val_mae: 15.9409
# Epoch 23/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 507.2809 - mae: 17.6138 - val_loss: 382.8535 - val_mae: 15.7403
# Epoch 24/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 465.1151 - mae: 16.8837 - val_loss: 443.7505 - val_mae: 15.9400
# Epoch 25/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 440.7798 - mae: 16.4120 - val_loss: 324.3031 - val_mae: 14.4929
# Epoch 26/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 375.1793 - mae: 15.1477 - val_loss: 299.7543 - val_mae: 13.3494
# Epoch 27/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 343.8582 - mae: 14.5083 - val_loss: 233.2771 - val_mae: 11.7608
# Epoch 28/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 318.2622 - mae: 13.9342 - val_loss: 231.1561 - val_mae: 11.8754
# Epoch 29/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 291.7671 - mae: 13.2539 - val_loss: 218.2014 - val_mae: 11.5682
# Epoch 30/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 262.6454 - mae: 12.6269 - val_loss: 158.6559 - val_mae: 9.8174
# Epoch 31/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 237.5487 - mae: 11.9915 - val_loss: 217.8833 - val_mae: 11.5688
# Epoch 32/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 232.5785 - mae: 11.8545 - val_loss: 133.6796 - val_mae: 9.0499
# Epoch 33/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 207.1520 - mae: 11.0318 - val_loss: 204.3528 - val_mae: 11.4539
# Epoch 34/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 161.8696 - mae: 9.8284 - val_loss: 148.3010 - val_mae: 9.6877
# Epoch 35/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 179.3103 - mae: 10.4051 - val_loss: 100.4214 - val_mae: 7.9794
# Epoch 36/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 149.6226 - mae: 9.4576 - val_loss: 228.7225 - val_mae: 11.9222
# Epoch 37/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 155.4888 - mae: 9.4429 - val_loss: 82.3786 - val_mae: 6.9704
# Epoch 38/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 148.3788 - mae: 9.3308 - val_loss: 174.5468 - val_mae: 10.4099
# Epoch 39/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 161.8400 - mae: 9.4147 - val_loss: 171.1837 - val_mae: 10.5750
# Epoch 40/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 127.0221 - mae: 8.4100 - val_loss: 55.6769 - val_mae: 5.7601
# Epoch 41/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 95.5778 - mae: 7.4436 - val_loss: 712.4986 - val_mae: 20.0410
# Epoch 42/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 122.5673 - mae: 8.1166 - val_loss: 254.6551 - val_mae: 13.0261
# Epoch 43/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 94.2673 - mae: 7.2460 - val_loss: 116.1183 - val_mae: 8.5209
# Epoch 44/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 98.6855 - mae: 7.4506 - val_loss: 76.1402 - val_mae: 6.9363
# Epoch 45/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 90.3683 - mae: 7.0845 - val_loss: 72.2528 - val_mae: 6.4801
# Epoch 46/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 83.0411 - mae: 6.6149 - val_loss: 167.4434 - val_mae: 10.0242
# Epoch 47/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 109.2822 - mae: 7.7685 - val_loss: 15.7779 - val_mae: 3.0368
# Epoch 48/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 85.3262 - mae: 6.7013 - val_loss: 164.6500 - val_mae: 10.0994
# Epoch 49/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 112.6973 - mae: 7.1330 - val_loss: 50.2011 - val_mae: 5.5143
# Epoch 50/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 92.6354 - mae: 6.7160 - val_loss: 28.1183 - val_mae: 4.0551
# Epoch 51/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 100.6523 - mae: 6.7570 - val_loss: 218.5204 - val_mae: 11.6647
# Epoch 52/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 67.5093 - mae: 5.4650 - val_loss: 14.9282 - val_mae: 2.9605
# Epoch 53/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 81.5822 - mae: 5.3238 - val_loss: 21.4751 - val_mae: 3.5827
# Epoch 54/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 65.3491 - mae: 5.2637 - val_loss: 5.0145 - val_mae: 1.5472
# Epoch 55/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 51.9235 - mae: 4.0751 - val_loss: 75.1129 - val_mae: 7.0901
# Epoch 56/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 71.2086 - mae: 5.3073 - val_loss: 16.5454 - val_mae: 3.1878
# Epoch 57/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 75.6685 - mae: 6.3761 - val_loss: 82.8900 - val_mae: 7.2444
# Epoch 58/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 70.3603 - mae: 5.7146 - val_loss: 48.1691 - val_mae: 5.4494
# Epoch 59/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 88.9232 - mae: 6.1014 - val_loss: 10.8521 - val_mae: 2.5072
# Epoch 60/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 84.6516 - mae: 5.4012 - val_loss: 9.5308 - val_mae: 2.3293
# Epoch 61/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 86.6645 - mae: 5.3151 - val_loss: 4.1480 - val_mae: 1.3834
# Epoch 62/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 54.7480 - mae: 4.6758 - val_loss: 45.9841 - val_mae: 5.4125
# Epoch 63/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 63.2433 - mae: 5.0974 - val_loss: 64.4766 - val_mae: 6.2935
# Epoch 64/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 61.3793 - mae: 5.4985 - val_loss: 3.6246 - val_mae: 1.1834
# Epoch 65/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 47.2979 - mae: 3.9906 - val_loss: 7.9829 - val_mae: 2.1320
# Epoch 66/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 64.0215 - mae: 4.9153 - val_loss: 14.3216 - val_mae: 2.9823
# Epoch 67/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 30.6566 - mae: 3.3629 - val_loss: 4.2553 - val_mae: 1.4272
# Epoch 68/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 59.1393 - mae: 4.5535 - val_loss: 654.8021 - val_mae: 21.4545
# Epoch 69/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 106.9870 - mae: 6.1639 - val_loss: 577.0228 - val_mae: 21.4389
# Epoch 70/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 113.5372 - mae: 5.3499 - val_loss: 4.0887 - val_mae: 1.3897
# Epoch 71/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 61.1535 - mae: 4.3221 - val_loss: 160.0937 - val_mae: 9.8413
# Epoch 72/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 110.0925 - mae: 6.5130 - val_loss: 35.4636 - val_mae: 5.2180
# Epoch 73/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 92.5828 - mae: 6.0210 - val_loss: 49.3928 - val_mae: 5.5831
# Epoch 74/75
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 103.7430 - mae: 5.6995 - val_loss: 56.7811 - val_mae: 6.1349
# Epoch 74: early stopping
# Restoring model weights from the end of the best epoch: 64.

# %% [markdown]
# Evaluating the model

# %%
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {test_mae:.2f}")
train_mae = history.history['mae']  # List of MAE values for each epoch
last_train_mae = train_mae[-1]  # Get the final Training MAE
print(f"Final Training MAE: {last_train_mae:.2f}")
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.6115 - mae: 1.1757
# Test MAE: 1.18
# Final Training MAE: 4.82

# %%
# Calculate the mean of the target variable (y_test)
y_test_mean = np.mean(y_test)

# Calculate percentage accuracy based on MAE and mean
percentage_accuracy_mae = (1 - (test_mae / y_test_mean)) * 100

print(f"Percentage Accuracy (MAE-based): {percentage_accuracy_mae:.2f}%")# Calculate the mean of the target variable (y_test)
y_test_mean = np.mean(y_test)

# Calculate percentage accuracy based on MAE and mean
percentage_accuracy_mae = (1 - (test_mae / y_test_mean)) * 100

print(f"Percentage Accuracy (MAE-based): {percentage_accuracy_mae:.2f}%")
# Out:
# Percentage Accuracy (MAE-based): 99.98%
# Percentage Accuracy (MAE-based): 99.98%

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file="model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
import matplotlib.pyplot as plt

# Assuming you have a trained model with `history`
plt.figure(figsize=(10, 5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score

# Get model predictions on test data
y_pred = model.predict(X_test)

# Compute R² Score
r2 = r2_score(y_test, y_pred)

# Convert to percentage accuracy
percentage_accuracy_r2 = r2 * 100

print(f"Percentage Accuracy (R-squared): {percentage_accuracy_r2:.2f}%")
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Percentage Accuracy (R-squared): 100.00%

# %%
model.save("airline_profit_model3.keras")
